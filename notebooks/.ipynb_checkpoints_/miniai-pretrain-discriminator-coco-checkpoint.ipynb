# %% [markdown]
# **Install dependencies**

# %%
# %%capture
# try:
#     import miniai
# except ImportError:
#     !git clone https://github.com/fastai/course22p2.git
#     !pip install -e ./course22p2

# %%
# %%capture
# !pip install -U torch torchvision torchaudio torcheval
# !pip install numpy pandas pillow wandb
# !pip install -U cjm_pil_utils cjm_kaggle_utils cjm_pytorch_utils cjm_pandas_utils

# %% [markdown]
# **Import dependencies**

# %%
from pathlib import Path
import hashlib
import json
import random
import multiprocessing
import math
import os
from functools import partial
from copy import copy
from glob import glob

from PIL import Image
import numpy as np
import timm
from tqdm.auto import tqdm
import gradio as gr

# Import pandas module for data manipulation
import pandas as pd

# Set options for Pandas DataFrame display
pd.set_option('max_colwidth', None)  # Do not truncate the contents of cells in the DataFrame
pd.set_option('display.max_rows', None)  # Display all rows in the DataFrame
pd.set_option('display.max_columns', None)  # Display all columns in the DataFrame

# Import PyTorch dependencies
import torch
import torch.nn as nn
from torchvision import transforms, models
import torchvision.transforms.functional as TF
from torch.utils.data import Dataset, DataLoader
from torcheval.tools import get_module_summary
from torcheval.metrics import MulticlassAccuracy

# Import fastai dependencies
import fastcore.all as fc
from miniai.datasets import DataLoaders
from miniai.conv import def_device
from miniai.learner import *
from miniai.activations import Hook, ActivationStats
from miniai.accel import MixedPrecision, AccelerateCB
from miniai.init import BatchTransformCB, GeneralRelu, init_weights, set_seed, conv
from miniai.sgd import BatchSchedCB
from miniai.resnet import ResBlock

# Import utility functions
from cjm_kaggle_utils.core import save_kaggle_creds, dl_kaggle
from cjm_pil_utils.core import resize_img, get_img_files, stack_imgs
from cjm_pytorch_utils.core import pil_to_tensor, tensor_to_pil, tensor_stats_df, get_torch_device
from cjm_pandas_utils.core import markdown_to_pandas

# %% [markdown]
# **Log into Weights & Biases**

# %%
import wandb
wandb.login()
# Out:
# wandb: Currently logged in as: millscj. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# **Set random number seeds**

# %%
set_seed(42)

# %% [markdown]
# **Set device and data type**

# %%
device = get_torch_device()
dtype = torch.float32
device, dtype
# Out:
# ('cuda', torch.float32)

# %% [markdown]
# **Enter Kaggle username and API token**

# %%
username = ""
key = ""

# %% [markdown]
# **Save Kaggle credentials to file**

# %%
save_kaggle_creds(username, key, overwrite=False)
# Out:
# Empty username.

# %% [markdown]
# **Define directory paths**

# %%
# Define path to store datasets
dataset_dir = Path("/mnt/980_1TB_1/Datasets/")
# Create the dataset directory if it does not exist
dataset_dir.mkdir(parents=True, exist_ok=True)
print(f"Dataset Directory: {dataset_dir}")
# Out:
# Dataset Directory: /mnt/980_1TB_1/Datasets

# %% [markdown]
# **Define Kaggle dataset**

# %%
# Set the name of the dataset
dataset_name = 'COCO_2014'

# Create the path to the directory where the dataset will be extracted
dataset_path = Path(f'{dataset_dir}/{dataset_name}')
print(f"Dataset Path: {dataset_path}")
# Out:
# Dataset Path: /mnt/980_1TB_1/Datasets/COCO_2014

# %%
src_img_dir = Path(dataset_path/"train2014")
src_img_dir
# Out:
# Path('/mnt/980_1TB_1/Datasets/COCO_2014/train2014')

# %% [markdown]
# **Get image paths**

# %%
# Get a list of the paths to the images in the images directory
img_paths = get_img_files(src_img_dir)

# Print the number of images in the images directory
print(len(img_paths))
# Out:
# 82783

# %% [markdown]
# **Display sample image**

# %%
# Choose a random image ID from the list of image IDs
img_path = random.choice(img_paths)

sample_img = Image.open(img_path)

greyscale_img = sample_img.convert("L").convert("RGB")

# Display the image
stack_imgs([sample_img, greyscale_img])
# Out:
# <PIL.Image.Image image mode=RGB size=758x640>

# %% [markdown]
# **Define training dataset class**

# %%
class ImageDataset(Dataset):
    def __init__(self, img_paths, classes, norm_stats, img_tfms):
        # Store the arguments as instance variables
        self.img_paths = img_paths
        self.classes = classes
        self.norm_stats = norm_stats
        self.img_tfms = img_tfms
        
        # Create a mapping from class names to class indices
        self.class_to_idx = {c: i for i, c in enumerate(self.classes)}

    def __len__(self):
        # Return the number of images in the dataset
        return len(self.img_paths)

    def __getitem__(self, index):
        # Get the path of the image at the given index
        img_path = self.img_paths[index]
        
        # Open the image
        image = Image.open(img_path).convert('RGB')
        
        greyscale = random.random() >= 0.5
        
        if greyscale:
            image = image.convert("L").convert("RGB")
        
        # Apply the image transformations
        image = self.img_tfms(image)
        
        return pil_to_tensor(image, *self.norm_stats).squeeze(0), int(greyscale)

# %% [markdown]
# **Set training and validation sets**

# %%
# Choose a subset of the image paths
# img_paths_subset = random.sample(img_paths, 70000)
# img_ids_subset = random.sample(img_ids, len(img_ids))
img_paths_subset = img_paths

# Shuffle the subset of image paths
random.shuffle(img_paths_subset)

# Define the percentage of the images that should be used for training
train_percentage = 0.9

# Calculate the index at which to split the subset of image paths into training and validation sets
split_index = int(len(img_paths_subset)*train_percentage)

# Split the subset of image paths into training and validation sets
train_paths = img_paths_subset[:split_index]
val_path = img_paths_subset[split_index:]

# %% [markdown]
# **Set training batch size**

# %%
bs = 32

# %% [markdown]
# **Initialize datasets**

# %%
class_names = ['color', 'greyscale']

# %%
train_sz = (296,296)

# normalization statistics for imagenet
imagenet_stats = [0.485, 0.456, 0.406], [0.229, 0.224, 0.225]


valid_tfms = [
    transforms.Resize(train_sz, interpolation=transforms.InterpolationMode.BILINEAR)
]

# create the validation dataset
valid_dataset = ImageDataset(img_paths=val_path, 
                             classes=class_names,
                             norm_stats=imagenet_stats,
                             img_tfms=transforms.Compose(valid_tfms))

train_tfms = copy(valid_tfms)
                             
# create the training dataset using the composed transformations
train_dataset = ImageDataset(img_paths=train_paths, 
                             classes=class_names,
                             norm_stats=imagenet_stats,
                             img_tfms=transforms.Compose(train_tfms))



# print the length of the training and validation datasets
len(train_dataset), len(valid_dataset)
# Out:
# (74504, 8279)

# %%
def denorm_img_tensor(img_tensor, mean, std):
    mean_tensor = torch.Tensor(mean).view(1,1,-1).permute(2, 0, 1)
    std_tensor = torch.Tensor(std).view(1,1,-1).permute(2, 0, 1)
    return img_tensor*std_tensor+mean_tensor

# %%
sample_data = train_dataset[0]
print(sample_data[1], train_dataset.classes[sample_data[1]])
tensor_to_pil(denorm_img_tensor(sample_data[0], *imagenet_stats))
# Out:
# 0 color
# <PIL.Image.Image image mode=RGB size=296x296>

# %% [markdown]
# **Inspect dataset sample**

# %%
tensor_stats_df(train_dataset[0][0])
# Out:
#                    0
# mean        0.869102
# std         1.015912
# min        -1.998031
# max             2.64
# shape  (3, 296, 296)

# %%
tensor_stats_df(valid_dataset[0][0])
# Out:
#                    0
# mean       -0.392016
# std         0.989393
# min        -1.804444
# max         2.395991
# shape  (3, 296, 296)

# %% [markdown]
# **Initialzie dataloaders**

# %%
train_dataloader = DataLoader(train_dataset, 
                              batch_size=bs, 
                              shuffle=True, 
                              num_workers=multiprocessing.cpu_count())

valid_dataloader = DataLoader(valid_dataset, batch_size=bs)

dls = DataLoaders(train_dataloader, valid_dataloader)

# Print the number of batches in the training and validation dataloaders
len(dls.train), len(dls.valid)
# Out:
# (2329, 259)

# %% [markdown]
# **List available ResNet18 models**

# %%
pd.DataFrame(timm.list_models('resnet18*', pretrained=True))
# Out:
#            0
# 0   resnet18
# 1  resnet18d

# %% [markdown]
# **Inspect config for ResNet18 model**

# %%
# Import the convnext module
from timm.models import resnet

# Choose the resnet model
resnet_model = 'resnet18d'

# Get the default configuration of the chosen model as a Pandas DataFrame
pd.DataFrame.from_dict(resnet.default_cfgs[resnet_model], orient='index')
# Out:
#                                                                                                                          0
# url            https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-weights/resnet18d_ra2-48a79e06.pth
# num_classes                                                                                                           1000
# input_size                                                                                                   (3, 224, 224)
# pool_size                                                                                                           (7, 7)
# crop_pct                                                                                                             0.875
# interpolation                                                                                                      bicubic
# mean                                                                                                 (0.485, 0.456, 0.406)
# std                                                                                                  (0.229, 0.224, 0.225)
# first_conv                                                                                                         conv1.0
# classifier                                                                                                              fc

# %% [markdown]
# **Load ResNet18 model**

# %%
# Load the resenet model
resnet18 = timm.create_model(resnet_model, pretrained=True, num_classes=len(class_names))

# Set the device and data type
resnet18 = resnet18.to(device=device, dtype=dtype).eval()
resnet18.device = device

# %% [markdown]
# **List available ConvNeXt Nano models**

# %%
pd.DataFrame(timm.list_models('convnext_nano*', pretrained=True))
# Out:
#                    0
# 0      convnext_nano
# 1  convnext_nano_ols

# %% [markdown]
# **Inspect config for convnext model**

# %%
# Import the convnext module
from timm.models import convnext

# Choose the convnext model
convnext_model = 'convnext_nano'

# Get the default configuration of the chosen model as a Pandas DataFrame
pd.DataFrame.from_dict(convnext.default_cfgs[convnext_model], orient='index')
# Out:
#                                                                                                                                    0
# url              https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/convnext_nano_d1h-7eb4bdea.pth
# num_classes                                                                                                                     1000
# input_size                                                                                                             (3, 224, 224)
# pool_size                                                                                                                     (7, 7)
# crop_pct                                                                                                                        0.95
# interpolation                                                                                                                bicubic
# mean                                                                                                           (0.485, 0.456, 0.406)
# std                                                                                                            (0.229, 0.224, 0.225)
# first_conv                                                                                                                    stem.0
# classifier                                                                                                                   head.fc
# test_input_size                                                                                                        (3, 288, 288)
# test_crop_pct                                                                                                                    1.0

# %% [markdown]
# **Load convnext_nano model**

# %%
# Load the convnext model
convnext = timm.create_model(convnext_model, pretrained=True, num_classes=len(class_names))

# Set the device and data type
convnext = convnext.to(device=device, dtype=dtype).eval()
convnext.device = device

# %% [markdown]
# **Select model**

# %%
model = resnet18
# model = convnext

# %% [markdown]
# **Get model summary**

# %%
# Define the input to the model
test_inp = torch.randn(1, 3, *train_sz).to(device)

# Get a summary of the model as a Pandas DataFrame
summary_df = markdown_to_pandas(f"{get_module_summary(model, [test_inp])}")

# Filter the summary to only contain Conv2d layers and the model
summary_df = summary_df[(summary_df.index == 0) | (summary_df['Type'] == 'Conv2d')]

# Remove the column "Contains Uninitialized Parameters?"
summary_df.drop('Contains Uninitialized Parameters?', axis=1)
# Out:
#       Type # Parameters # Trainable Parameters Size (bytes) Forward FLOPs  \
# 0   ResNet       11.2 M                 11.2 M       44.8 M         3.7 G
# 2   Conv2d          864                    864        3.5 K        18.9 M
# 5   Conv2d        9.2 K                  9.2 K       36.9 K         201 M
# 8   Conv2d       18.4 K                 18.4 K       73.7 K         403 M
# 14  Conv2d       36.9 K                 36.9 K        147 K         201 M
# 19  Conv2d       36.9 K                 36.9 K        147 K         201 M
# 23  Conv2d       36.9 K                 36.9 K        147 K         201 M
# 28  Conv2d       36.9 K                 36.9 K        147 K         201 M
# 33  Conv2d       73.7 K                 73.7 K        294 K         100 M
# 38  Conv2d        147 K                  147 K        589 K         201 M
# 43  Conv2d        8.2 K                  8.2 K       32.8 K        11.2 M
# 46  Conv2d        147 K                  147 K        589 K         201 M
# 51  Conv2d        147 K                  147 K        589 K         201 M
# 56  Conv2d        294 K                  294 K        1.2 M         106 M
# 61  Conv2d        589 K                  589 K        2.4 M         212 M
# 66  Conv2d       32.8 K                 32.8 K        131 K        11.8 M
# 69  Conv2d        589 K                  589 K        2.4 M         212 M
# 74  Conv2d        589 K                  589 K        2.4 M         212 M
# 79  Conv2d        1.2 M                  1.2 M        4.7 M         117 M
# 84  Conv2d        2.4 M                  2.4 M        9.4 M         235 M
# 89  Conv2d        131 K                  131 K        524 K        13.1 M
# 92  Conv2d        2.4 M                  2.4 M        9.4 M         235 M
# 97  Conv2d        2.4 M                  2.4 M        9.4 M         235 M
#
#    Backward FLOPs            In size           Out size
# 0           7.5 G   [1, 3, 296, 296]             [1, 2]
# 2          18.9 M   [1, 3, 296, 296]  [1, 32, 148, 148]
# 5           403 M  [1, 32, 148, 148]  [1, 32, 148, 148]
# 8           807 M  [1, 32, 148, 148]  [1, 64, 148, 148]
# 14          403 M    [1, 64, 74, 74]    [1, 64, 74, 74]
# 19          403 M    [1, 64, 74, 74]    [1, 64, 74, 74]
# 23          403 M    [1, 64, 74, 74]    [1, 64, 74, 74]
# 28          403 M    [1, 64, 74, 74]    [1, 64, 74, 74]
# 33          201 M    [1, 64, 74, 74]   [1, 128, 37, 37]
# 38          403 M   [1, 128, 37, 37]   [1, 128, 37, 37]
# 43         22.4 M    [1, 64, 37, 37]   [1, 128, 37, 37]
# 46          403 M   [1, 128, 37, 37]   [1, 128, 37, 37]
# 51          403 M   [1, 128, 37, 37]   [1, 128, 37, 37]
# 56          212 M   [1, 128, 37, 37]   [1, 256, 19, 19]
# 61          425 M   [1, 256, 19, 19]   [1, 256, 19, 19]
# 66         23.7 M   [1, 128, 19, 19]   [1, 256, 19, 19]
# 69          425 M   [1, 256, 19, 19]   [1, 256, 19, 19]
# 74          425 M   [1, 256, 19, 19]   [1, 256, 19, 19]
# 79          235 M   [1, 256, 19, 19]   [1, 512, 10, 10]
# 84          471 M   [1, 512, 10, 10]   [1, 512, 10, 10]
# 89         26.2 M   [1, 256, 10, 10]   [1, 512, 10, 10]
# 92          471 M   [1, 512, 10, 10]   [1, 512, 10, 10]
# 97          471 M   [1, 512, 10, 10]   [1, 512, 10, 10]

# %% [markdown]
# **Define training callbacks**

# %%
class WandBCB(MetricsCB):
    order=100
    def __init__(self, config, *ms, project:str, name:str=None, **metrics):
        fc.store_attr()
        self.train = False
        super().__init__(*ms, **metrics)
        
    def before_fit(self, learn): 
        if self.name:
            wandb.init(project=self.project, name=self.name, config=self.config)
        else:
            wandb.init(project=self.project, config=self.config)
    def after_fit(self, learn): wandb.finish()

    def _log(self, d): 
        if self.train: 
            wandb.log({'train_'+m:float(d[m]) for m in self.all_metrics})
        else: 
            wandb.log({'val_'+m:float(d[m]) for m in self.all_metrics})
        
    def sample_figure(self, learn):
        with torch.no_grad():
            samples = sample(learn.model, (16, 3, 32, 32))
        s = (samples[-1] + 0.5).clamp(0,1)
        plt.clf()
        fig, axs = get_grid(16)
        for im,ax in zip(s[:16], axs.flat): show_image(im, ax=ax)
        return fig

    def after_batch(self, learn):
        super().after_batch(learn) 
        wandb.log({'loss':learn.loss})
        
    def after_epoch(self, learn):
        self.train = learn.training
        super().after_epoch(learn)

# %%
class OutOfBoundsCB(Callback):
    """
    A callback that exits the training session if the loss is not NaN or infinite.
    """
    def __init__(self, msg="Loss out of bounds"):
        fc.store_attr()
        
    def after_loss(self, learn):
        """
        Check if the loss is NaN or infinite.
        """
        if learn.loss.detach().isnan() or learn.loss.detach().isinf(): 
            print(self.msg)
            raise CancelFitException()

# %%
def tfm_batch(b, tfm_x=fc.noop, tfm_y = fc.noop): return tfm_x(b[0]),tfm_y(b[1])

# %%
tfms = nn.Sequential(
#     RandSquareCopy(pct=0.15, max_num=1),
#     RandPixelCopy(pct=0.015), 
#     RandSquarePixelCopy(square_pct=0.15, pixel_pct=0.5, min_num=1, max_num=1),
)
augcb = BatchTransformCB(partial(tfm_batch, tfm_x=tfms), on_val=False)

# %%
lr = 1e-3
epochs = 5

# %% [markdown]
# **Configure Weights & Biases project**

# %%
project_name = "miniai_pretrain_discriminator"
run_name = "color-greyscale"
project_config = {'lr':lr, 'epochs':epochs}

# %% [markdown]
# **Initialize callbacks**

# %%
wandbcb =  WandBCB(config=project_config, 
                   project=project_name,
                   name=run_name,
                   accuracy=MulticlassAccuracy()
                  )

metrics = MetricsCB(accuracy=MulticlassAccuracy())

cbs = [MixedPrecision(), 
       OutOfBoundsCB(),
       DeviceCB(), 
       metrics, 
       ProgressCB(plot=False),
       wandbcb,
#        augcb,
      ]

# %% [markdown]
# **Set optimizer**

# %%
opt_func = partial(torch.optim.AdamW, eps=1e-5)

# %%
tmax = epochs * len(dls.train)
sched = partial(torch.optim.lr_scheduler.OneCycleLR, max_lr=lr, total_steps=tmax)
xtra = [BatchSchedCB(sched)]
learn = TrainLearner(model, dls, torch.nn.functional.cross_entropy, lr=lr, cbs=cbs+xtra, opt_func=opt_func)

# %%
learn.fit(epochs)
# Out:
# Tracking run with wandb version 0.13.10
# Run data is saved locally in <code>/media/innom-dt/Samsung_T3/Projects/GitHub/fastai-2022p2-notes/notebooks/wandb/run-20230224_153347-3qpz36ig</code>
# Syncing run <strong><a href='https://wandb.ai/millscj/miniai_pretrain_discriminator/runs/3qpz36ig' target="_blank">color-greyscale</a></strong> to <a href='https://wandb.ai/millscj/miniai_pretrain_discriminator' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/millscj/miniai_pretrain_discriminator' target="_blank">https://wandb.ai/millscj/miniai_pretrain_discriminator</a>
#  View run at <a href='https://wandb.ai/millscj/miniai_pretrain_discriminator/runs/3qpz36ig' target="_blank">https://wandb.ai/millscj/miniai_pretrain_discriminator/runs/3qpz36ig</a>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='1' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       20.00% [1/5 04:05&lt;16:23]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.978</td>
#       <td>0.093</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.570</td>
#       <td>3.940</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='276' class='' max='2329' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       11.85% [276/2329 00:24&lt;03:01 0.169]
#     </div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 learn.fit(epochs)
#
# File /media/innom-dt/Samsung_T3/Projects/GitHub/fastai-2022p2-notes/notebooks/course22p2/miniai/learner.py:170, in Learner.fit(self, n_epochs, train, valid, cbs, lr)
#     168     if lr is None: lr = self.lr
#     169     if self.opt_func: self.opt = self.opt_func(self.model.parameters(), lr)
# --> 170     self._fit(train, valid)
#     171 finally:
#     172     for cb in cbs: self.cbs.remove(cb)
#
# File /media/innom-dt/Samsung_T3/Projects/GitHub/fastai-2022p2-notes/notebooks/course22p2/miniai/learner.py:121, in with_cbs.__call__.<locals>._f(o, *args, **kwargs)
#     119 try:
#     120     o.callback(f'before_{self.nm}')
# --> 121     f(o, *args, **kwargs)
#     122     o.callback(f'after_{self.nm}')
#     123 except globals()[f'Cancel{self.nm.title()}Exception']: pass
#
# File /media/innom-dt/Samsung_T3/Projects/GitHub/fastai-2022p2-notes/notebooks/course22p2/miniai/learner.py:158, in Learner._fit(self, train, valid)
#     155 @with_cbs('fit')
#     156 def _fit(self, train, valid):
#     157     for self.epoch in self.epochs:
# --> 158         if train: self.one_epoch(True)
#     159         if valid: torch.no_grad()(self.one_epoch)(False)
#
# File /media/innom-dt/Samsung_T3/Projects/GitHub/fastai-2022p2-notes/notebooks/course22p2/miniai/learner.py:153, in Learner.one_epoch(self, training)
#     151 self.model.train(training)
#     152 self.dl = self.dls.train if training else self.dls.valid
# --> 153 self._one_epoch()
#
# File /media/innom-dt/Samsung_T3/Projects/GitHub/fastai-2022p2-notes/notebooks/course22p2/miniai/learner.py:121, in with_cbs.__call__.<locals>._f(o, *args, **kwargs)
#     119 try:
#     120     o.callback(f'before_{self.nm}')
# --> 121     f(o, *args, **kwargs)
#     122     o.callback(f'after_{self.nm}')
#     123 except globals()[f'Cancel{self.nm.title()}Exception']: pass
#
# File /media/innom-dt/Samsung_T3/Projects/GitHub/fastai-2022p2-notes/notebooks/course22p2/miniai/learner.py:148, in Learner._one_epoch(self)
#     146 @with_cbs('epoch')
#     147 def _one_epoch(self):
# --> 148     for self.iter,self.batch in enumerate(self.dl): self._one_batch()
#
# File /media/innom-dt/Samsung_T3/Projects/GitHub/fastai-2022p2-notes/notebooks/course22p2/miniai/learner.py:122, in with_cbs.__call__.<locals>._f(o, *args, **kwargs)
#     120     o.callback(f'before_{self.nm}')
#     121     f(o, *args, **kwargs)
# --> 122     o.callback(f'after_{self.nm}')
#     123 except globals()[f'Cancel{self.nm.title()}Exception']: pass
#     124 finally: o.callback(f'cleanup_{self.nm}')
#
# File /media/innom-dt/Samsung_T3/Projects/GitHub/fastai-2022p2-notes/notebooks/course22p2/miniai/learner.py:178, in Learner.callback(self, method_nm)
# --> 178 def callback(self, method_nm): run_cbs(self.cbs, method_nm, self)
#
# File /media/innom-dt/Samsung_T3/Projects/GitHub/fastai-2022p2-notes/notebooks/course22p2/miniai/learner.py:35, in run_cbs(cbs, method_nm, learn)
#      33 for cb in sorted(cbs, key=attrgetter('order')):
#      34     method = getattr(cb, method_nm, None)
# ---> 35     if method is not None: method(learn)
#
# File /media/innom-dt/Samsung_T3/Projects/GitHub/fastai-2022p2-notes/notebooks/course22p2/miniai/learner.py:71, in MetricsCB.after_batch(self, learn)
#      70 def after_batch(self, learn):
# ---> 71     x,y,*_ = to_cpu(learn.batch)
#      72     for m in self.metrics.values(): m.update(to_cpu(learn.preds), y)
#      73     self.loss.update(to_cpu(learn.loss), weight=len(x))
#
# File /media/innom-dt/Samsung_T3/Projects/GitHub/fastai-2022p2-notes/notebooks/course22p2/miniai/learner.py:48, in to_cpu(x)
#      46 def to_cpu(x):
#      47     if isinstance(x, Mapping): return {k:to_cpu(v) for k,v in x.items()}
# ---> 48     if isinstance(x, list): return [to_cpu(o) for o in x]
#      49     if isinstance(x, tuple): return tuple(to_cpu(list(x)))
#      50     return x.detach().cpu()
#
# File /media/innom-dt/Samsung_T3/Projects/GitHub/fastai-2022p2-notes/notebooks/course22p2/miniai/learner.py:48, in <listcomp>(.0)
#      46 def to_cpu(x):
#      47     if isinstance(x, Mapping): return {k:to_cpu(v) for k,v in x.items()}
# ---> 48     if isinstance(x, list): return [to_cpu(o) for o in x]
#      49     if isinstance(x, tuple): return tuple(to_cpu(list(x)))
#      50     return x.detach().cpu()
#
# File /media/innom-dt/Samsung_T3/Projects/GitHub/fastai-2022p2-notes/notebooks/course22p2/miniai/learner.py:50, in to_cpu(x)
#      48 if isinstance(x, list): return [to_cpu(o) for o in x]
#      49 if isinstance(x, tuple): return tuple(to_cpu(list(x)))
# ---> 50 return x.detach().cpu()
#
# KeyboardInterrupt:

# %% [markdown]
# **Test model**

# %%
# Choose a random image ID from the list of image IDs
img_path = random.choice(img_paths)

print(f"Class: {img_path.parent.name}")

sample_img = Image.open(img_path)
inp_img = resize_img(sample_img.copy(), 288)

img_tensor = pil_to_tensor(inp_img, *imagenet_stats).to(device=device)

with torch.no_grad():
        pred = learn.model(img_tensor)
        
pred_class = train_dataset.classes[torch.argmax(torch.sigmoid(pred))]
        
print(f"Predicted Class: {pred_class}")


sample_img
# Out:
# Class: four
# Predicted Class: four
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>

# %% [markdown]
# **Get test image paths**

# %%
img_dict = {path.stem: path for path in img_paths}

subset_dict = {path.stem: path for path in img_paths_subset}

test_paths = [path for k,path in img_dict.items() if k not in subset_dict]
len(test_paths)
# Out:
# 78878

# %% [markdown]
# **Perform inference on test set**

# %%
wrong_imgs = []

for path in tqdm(img_paths_subset):
    target_cls = "color"

    sample_img = Image.open(path)
    sample_img = resize_img(sample_img, 288)

    img_tensor = pil_to_tensor(sample_img, *imagenet_stats).to(device=device)

    with torch.no_grad():
            pred = learn.model(img_tensor)

    pred_cls = train_dataset.classes[torch.argmax(torch.sigmoid(pred))]
    
    if pred_cls != target_cls: wrong_imgs.append(path)

len(wrong_imgs)
# Out:
#   0%|          | 0/105665 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[53], line 12
#       9 img_tensor = pil_to_tensor(sample_img, *imagenet_stats).to(device=device)
#      11 with torch.no_grad():
# ---> 12         pred = learn.model(img_tensor)
#      14 pred_cls = train_dataset.classes[torch.argmax(torch.sigmoid(pred))]
#      16 if pred_cls != target_cls: wrong_imgs.append(path)
#
# File ~/mambaforge/envs/sd-testing/lib/python3.10/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/mambaforge/envs/sd-testing/lib/python3.10/site-packages/timm/models/resnet.py:730, in ResNet.forward(self, x)
#     729 def forward(self, x):
# --> 730     x = self.forward_features(x)
#     731     x = self.forward_head(x)
#     732     return x
#
# File ~/mambaforge/envs/sd-testing/lib/python3.10/site-packages/timm/models/resnet.py:709, in ResNet.forward_features(self, x)
#     708 def forward_features(self, x):
# --> 709     x = self.conv1(x)
#     710     x = self.bn1(x)
#     711     x = self.act1(x)
#
# File ~/mambaforge/envs/sd-testing/lib/python3.10/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/mambaforge/envs/sd-testing/lib/python3.10/site-packages/torch/nn/modules/container.py:204, in Sequential.forward(self, input)
#     202 def forward(self, input):
#     203     for module in self:
# --> 204         input = module(input)
#     205     return input
#
# File ~/mambaforge/envs/sd-testing/lib/python3.10/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/mambaforge/envs/sd-testing/lib/python3.10/site-packages/torch/nn/modules/conv.py:462, in Conv2d.forward(self, input)
#     456         return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     457                         weight, bias, self.stride,
#     458                         _pair(0), self.dilation, self.groups)
#     459     return F.conv2d(input, weight, bias, self.stride,
#     460                     self.padding, self.dilation, self.groups)
# --> 462 def forward(self, input: Tensor) -> Tensor:
#     463     return self._conv_forward(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %% [markdown]
# **Set checkpoint directory**

# %%
# Create a directory to store the checkpoints if it does not already exist
checkpoint_dir = Path("./discriminator_checkpoints/")
checkpoint_dir.mkdir(parents=True, exist_ok=True)

# Print the checkpoint path
checkpoint_dir
# Out:
# Path('discriminator_checkpoints')

# %% [markdown]
# **Save model checkpoint**

# %%
torch.save(learn.model.state_dict(), checkpoint_dir/f"resnet18d-{run_name}.pth")

# %% [markdown]
# **Inspect the number of wrong predictions per class**

# %%
wrong_imgs_df = pd.DataFrame(wrong_imgs)
wrong_imgs_df['class'] = wrong_imgs_df.apply(lambda row: Path(row[0]).parent.stem, axis=1)

class_dist_df = wrong_imgs_df['class'].value_counts().to_frame().rename(columns={"class":run_name})
class_dist_df.rename_axis("class", inplace=True)
class_dist_df
# Out:
#                  trivial-aug-item-1
# class
# one                              72
# peace                            68
# three                            58
# stop                             46
# like                             44
# two_up                           41
# call                             39
# ok                               39
# four                             36
# fist                             32
# no_gesture                       31
# two_up_inverted                  30
# peace_inverted                   25
# three2                           23
# dislike                          19
# stop_inverted                    19
# palm                             16
# rock                             16
# mute                              8

# %% [markdown]
# **Save DataFrame**

# %%
class_dist_df_path = checkpoint_dir/f"class_dist_df-{run_name}.json"
class_dist_df.to_json(class_dist_df_path)

# %% [markdown]
# **Get a list of json files**

# %%
# Get a list of paths to JSON files in the 'annotation_dir' directory
df_paths = glob(os.path.join(checkpoint_dir, "*.json"))

# Display the JSON file paths using a Pandas DataFrame
pd.DataFrame(df_paths)
# Out:
#                                                               0
# 0                hagrid_checkpoints/class_dist_df-baseline.json
# 1         hagrid_checkpoints/class_dist_df-rand-pixel-cp-1.json
# 2        hagrid_checkpoints/class_dist_df-rand-square-cp-1.json
# 3  hagrid_checkpoints/class_dist_df-rand-square-pixel-cp-1.json
# 4      hagrid_checkpoints/class_dist_df-trivial-aug-item-1.json

# %% [markdown]
# **Load and concatenate DataFrames**

# %%
class_dist_dfs = (pd.read_json(f).rename_axis('class') for f in df_paths)

class_dist_agg_df = pd.concat(class_dist_dfs, axis=1, sort=False)

# Compute the sums along the columns axis
sums = class_dist_agg_df.sum(axis=0)

# Add a new row with the sums using the loc[] function
class_dist_agg_df.loc['Total'] = sums

class_dist_agg_df
# Out:
#                  baseline  rand-pixel-cp-1  rand-square-cp-1  \
# class
# call                   52               57                41
# dislike                26               30                25
# fist                   50               38                30
# four                   56               51                36
# like                   55               49                50
# mute                   17               30                17
# no_gesture             50               28                51
# ok                     38               49                39
# one                    58               54                60
# palm                   33               33                38
# peace                  64               60                84
# peace_inverted         23               23                15
# rock                   49               35                39
# stop                   59               47                60
# stop_inverted          25               25                16
# three                  48               59                61
# three2                 19               14                24
# two_up                 42               42                33
# two_up_inverted        24               27                25
# Total                 788              751               744
#
#                  rand-square-pixel-cp-1  trivial-aug-item-1
# class
# call                                 34                  39
# dislike                              23                  19
# fist                                 43                  32
# four                                 32                  36
# like                                 45                  44
# mute                                 30                   8
# no_gesture                           42                  31
# ok                                   52                  39
# one                                  63                  72
# palm                                 32                  16
# peace                                93                  68
# peace_inverted                       25                  25
# rock                                 29                  16
# stop                                 51                  46
# stop_inverted                        11                  19
# three                                61                  58
# three2                               23                  23
# two_up                               39                  41
# two_up_inverted                      21                  30
# Total                               749                 662
