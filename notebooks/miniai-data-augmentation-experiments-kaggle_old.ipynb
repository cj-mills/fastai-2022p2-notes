# %% [markdown]
# **Install dependencies**

# %%
# %%capture
# try:
#     import miniai
# except ImportError:
#     !git clone https://github.com/fastai/course22p2.git
#     !pip install -e ./course22p2

# %%
# %%capture
# !pip install torch torchvision torchaudio torcheval
# !pip install numpy pandas pillow wandb
# !pip install cjm_pil_utils cjm_kaggle_utils cjm_pytorch_utils cjm_pandas_utils

# %% [markdown]
# **Import dependencies**

# %%
from pathlib import Path
import hashlib
import json
import random
import multiprocessing
import math
import os
from functools import partial
from copy import copy
from glob import glob

from PIL import Image
import numpy as np
import timm
from tqdm.auto import tqdm

# Import pandas module for data manipulation
import pandas as pd

# Set options for Pandas DataFrame display
pd.set_option('max_colwidth', None)  # Do not truncate the contents of cells in the DataFrame
pd.set_option('display.max_rows', None)  # Display all rows in the DataFrame
pd.set_option('display.max_columns', None)  # Display all columns in the DataFrame

# Import PyTorch dependencies
import torch
import torch.nn as nn
from torchvision import transforms, models
import torchvision.transforms.functional as TF
from torch.utils.data import Dataset, DataLoader
from torcheval.tools import get_module_summary
from torcheval.metrics import MulticlassAccuracy

# Import fastai dependencies
import fastcore.all as fc
from miniai.datasets import DataLoaders
from miniai.conv import def_device
from miniai.learner import *
from miniai.activations import Hook, ActivationStats
from miniai.accel import MixedPrecision, AccelerateCB
from miniai.init import BatchTransformCB, GeneralRelu, init_weights, set_seed, conv
from miniai.sgd import BatchSchedCB
from miniai.resnet import ResBlock

# Import utility functions
from cjm_kaggle_utils.core import save_kaggle_creds, dl_kaggle
from cjm_pil_utils.core import resize_img, get_img_files, stack_imgs
from cjm_pytorch_utils.core import pil_to_tensor, tensor_to_pil, tensor_stats_df, get_torch_device
from cjm_pandas_utils.core import markdown_to_pandas, display_df

# %% [markdown]
# **Log into Weights & Biases**

# %%
import wandb
wandb.login()
# Out:
# wandb: Currently logged in as: millscj. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# **Set random number seeds**

# %%
set_seed(42)

# %% [markdown]
# **Set device and data type**

# %%
device = get_torch_device()
dtype = torch.float32
device, dtype
# Out:
# ('cuda', torch.float32)

# %% [markdown]
# **Enter Kaggle username and API token**

# %%
username = ""
key = ""

# %% [markdown]
# **Save Kaggle credentials to file**

# %%
save_kaggle_creds(username, key, overwrite=False)
# Out:
# Empty username.

# %% [markdown]
# **Define directory paths**

# %%
# Define path to store datasets
dataset_dir = Path("./Datasets/")
# Create the dataset directory if it does not exist
dataset_dir.mkdir(parents=True, exist_ok=True)
print(f"Dataset Directory: {dataset_dir}")

# Define path to store archive files
archive_dir = dataset_dir/'../Archive'
# Create the archive directory if it does not exist
archive_dir.mkdir(parents=True, exist_ok=True)
print(f"Archive Directory: {archive_dir}")
# Out:
# Dataset Directory: /mnt/980_1TB_2/Datasets
# Archive Directory: /mnt/980_1TB_2/Datasets/../Archive

# %% [markdown]
# **Define Kaggle dataset**

# %%
# Set the name of the dataset
dataset_name = 'hagrid-classification-512p-no-gesture-150k'

# Construct the Kaggle dataset name by combining the username and dataset name
kaggle_dataset = f'innominate817/{dataset_name}'

# Create the path to the zip file that contains the dataset
archive_path = Path(f'{archive_dir}/{dataset_name}.zip')
print(f"Archive Path: {archive_path}")

# Create the path to the directory where the dataset will be extracted
dataset_path = Path(f'{dataset_dir}/{dataset_name}')
print(f"Dataset Path: {dataset_path}")
# Out:
# Archive Path: /mnt/980_1TB_2/Datasets/../Archive/hagrid-classification-512p-no-gesture-150k.zip
# Dataset Path: /mnt/980_1TB_2/Datasets/hagrid-classification-512p-no-gesture-150k

# %% [markdown]
# **Download Kaggle dataset**

# %%
dl_kaggle(kaggle_dataset, archive_path, dataset_path)
# Out:
# Dataset already downloaded

# %% [markdown]
# **Get image classes**

# %%
# Get all subfolders within the dataset_path
folders = [folder for folder in dataset_path.glob('*/') if folder.is_dir()]

# Store the folder names
class_names = [f.name for f in folders]

# Print the list of class names
display_df(pd.DataFrame(class_names))
# Out:
# <style type="text/css">
# #T_ee952 th {
#   text-align: left;
# }
# #T_ee952_row0_col0, #T_ee952_row1_col0, #T_ee952_row2_col0, #T_ee952_row3_col0, #T_ee952_row4_col0, #T_ee952_row5_col0, #T_ee952_row6_col0, #T_ee952_row7_col0, #T_ee952_row8_col0, #T_ee952_row9_col0, #T_ee952_row10_col0, #T_ee952_row11_col0, #T_ee952_row12_col0, #T_ee952_row13_col0, #T_ee952_row14_col0, #T_ee952_row15_col0, #T_ee952_row16_col0, #T_ee952_row17_col0, #T_ee952_row18_col0 {
#   width: auto;
#   text-align: left;
# }
# </style>
# <table id="T_ee952">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ee952_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ee952_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ee952_row0_col0" class="data row0 col0" >call</td>
#     </tr>
#     <tr>
#       <th id="T_ee952_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ee952_row1_col0" class="data row1 col0" >dislike</td>
#     </tr>
#     <tr>
#       <th id="T_ee952_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ee952_row2_col0" class="data row2 col0" >fist</td>
#     </tr>
#     <tr>
#       <th id="T_ee952_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ee952_row3_col0" class="data row3 col0" >four</td>
#     </tr>
#     <tr>
#       <th id="T_ee952_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ee952_row4_col0" class="data row4 col0" >like</td>
#     </tr>
#     <tr>
#       <th id="T_ee952_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ee952_row5_col0" class="data row5 col0" >mute</td>
#     </tr>
#     <tr>
#       <th id="T_ee952_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ee952_row6_col0" class="data row6 col0" >no_gesture</td>
#     </tr>
#     <tr>
#       <th id="T_ee952_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ee952_row7_col0" class="data row7 col0" >ok</td>
#     </tr>
#     <tr>
#       <th id="T_ee952_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ee952_row8_col0" class="data row8 col0" >one</td>
#     </tr>
#     <tr>
#       <th id="T_ee952_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ee952_row9_col0" class="data row9 col0" >palm</td>
#     </tr>
#     <tr>
#       <th id="T_ee952_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_ee952_row10_col0" class="data row10 col0" >peace</td>
#     </tr>
#     <tr>
#       <th id="T_ee952_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_ee952_row11_col0" class="data row11 col0" >peace_inverted</td>
#     </tr>
#     <tr>
#       <th id="T_ee952_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_ee952_row12_col0" class="data row12 col0" >rock</td>
#     </tr>
#     <tr>
#       <th id="T_ee952_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_ee952_row13_col0" class="data row13 col0" >stop</td>
#     </tr>
#     <tr>
#       <th id="T_ee952_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_ee952_row14_col0" class="data row14 col0" >stop_inverted</td>
#     </tr>
#     <tr>
#       <th id="T_ee952_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_ee952_row15_col0" class="data row15 col0" >three</td>
#     </tr>
#     <tr>
#       <th id="T_ee952_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_ee952_row16_col0" class="data row16 col0" >three2</td>
#     </tr>
#     <tr>
#       <th id="T_ee952_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_ee952_row17_col0" class="data row17 col0" >two_up</td>
#     </tr>
#     <tr>
#       <th id="T_ee952_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_ee952_row18_col0" class="data row18 col0" >two_up_inverted</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Get image paths**

# %%
# Get a list of all image file paths from the given folders
img_paths = [get_img_files(folder) for folder in folders]

# Flatten the list of lists into a single list
img_paths = [path for class_paths in img_paths for path in class_paths]

# Get the number of image file paths
len(img_paths)
# Out:
# 153787

# %% [markdown]
# **Display sample image**

# %%
# Select a random image path from the list of image paths
img_path = random.choice(img_paths)

# Print the name of the class of the image, which is the name of the parent folder
print(f"Class: {img_path.parent.name}")

# Open the image using the path
sample_img = Image.open(img_path)

# Display the image
sample_img
# Out:
# Class: like
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>

# %% [markdown]
# **Random Square Copy Transform**

# %%
def rand_square_copy(img_tensor:torch.Tensor, pct:float):
    """
    Copy data from a randomly selected square region to another randomly selected square region of an image tensor.

    Args:
    img_tensor (torch.Tensor): The input image tensor.
    pct (float): The percentage of the image tensor's size to be used as the side length of the square regions.

    Returns:
    torch.Tensor: The modified input image tensor.
    """
    
    # Get the shape of the tensor
    h, w = img_tensor.shape[-2:]
    
    # Calculate the size of the square
    szx = int(pct * h)
    szy = int(pct * w)
    
    # Calculate the top-left coordinate of the first square
    stx1 = int(random.random() * (1 - pct) * h)
    sty1 = int(random.random() * (1 - pct) * w)
    
    # Calculate the top-left coordinate of the second square
    stx2 = int(random.random() * (1 - pct) * h)
    sty2 = int(random.random() * (1 - pct) * w)
    
    # Copy the data from the second square to the first square
    img_tensor[..., stx1:stx1 + szx, sty1:sty1 + szy] = img_tensor[..., stx2:stx2 + szx, sty2:sty2 + szy]
    
    # Return the modified input img_tensor
    return img_tensor

# %%
class RandSquareCopy(nn.Module):
    def __init__(self, pct=0.2, min_num=0, max_num=4):
        """
        A PyTorch module that applies the `rand_square_copy` function to an input tensor multiple times.

        Args:
        pct (float, optional): The percentage of the tensor's size to be used as the side length of 
                               the square regions.
        min_num (int, optional): The minimum number of times to apply the `rand_square_copy` function.
        max_num (int, optional): The maximum number of times to apply the `rand_square_copy` function.
        """
        super().__init__()
        self.pct = pct
        self.min_num = min_num
        self.max_num = max_num
        
    def forward(self, x): 
        # Apply the `rand_square_copy` function to the input tensor multiple times
        for i in range(random.randint(self.min_num, self.max_num)):
            x = rand_square_copy(x, max(0.1,random.random()*self.pct))
        return x

# %% [markdown]
# **Test the transform**

# %%
rand_square_copy_tf = RandSquareCopy(pct=0.2, min_num=1, max_num=1)

# Convert the PIL image to a tensor
img_tensor = transforms.PILToTensor()(sample_img)
print(img_tensor.shape)

# Apply the `rand_square_copy_tf` transform to the image tensor
tensor_to_pil(rand_square_copy_tf(img_tensor))
# Out:
# torch.Size([3, 512, 512])
# <PIL.Image.Image image mode=RGB size=512x512>

# %% [markdown]
# **Random Pixel Copy Transform**

# %%
def rand_pixel_copy(img_tensor:torch.Tensor, pct:float=0.2):
    """
    Copy data from a randomly selected set of pixels to another randomly selected set of pixels of a image tensor.

    Args:
    img_tensor (torch.Tensor): The input image tensor.
    pct (float, optional): The percentage of the total number of pixels to be selected as the source and target sets
                           of pixels.
    
    Returns:
    torch.Tensor: The modified input image tensor.
    """
    
    src_dim = img_tensor.dim()
    
    img_tensor = img_tensor.unsqueeze(0) if src_dim == 3 else img_tensor
    
    # Get the shape of the img_tensor
    b, c, h, w = img_tensor.shape
    
    # Calculate the number of pixels to be selected
    num_pixels = int(img_tensor[-1:].numel() * pct)
    
    # Select the source pixel indices
    source_indices = torch.LongTensor(num_pixels, 2).random_(0, h * w)
    source_indices[:, 0] = source_indices[:, 0] // w
    source_indices[:, 1] = source_indices[:, 1] % w
    
    # Select the target pixel indices
    target_indices = torch.LongTensor(num_pixels, 2).random_(0, h * w)
    target_indices[:, 0] = target_indices[:, 0] // w
    target_indices[:, 1] = target_indices[:, 1] % w
    
    # Get the indices of the channels
    c_indices = torch.arange(c).repeat(num_pixels, 1).t()
    
    # Copy the pixels
    source_pixels = img_tensor[:, c_indices, source_indices[:, 0], source_indices[:, 1]]
    img_tensor[:, c_indices, target_indices[:, 0], target_indices[:, 1]] = source_pixels
    
    return img_tensor.squeeze(0) if src_dim == 3 else img_tensor

# %%
class RandPixelCopy(nn.Module):
    def __init__(self, pct=0.1):
        """
        A PyTorch module that applies the `rand_pixel_copy` function to an input tensor.

        Args:
        pct (float, optional): The maximum percentage of the tensor's pixels to be copied.
        """
        super().__init__()
        self.pct = pct
        
    def forward(self, x):
        # Apply the `rand_pixel_copy` function to the input tensor
        return rand_pixel_copy(x, max(0.0025, random.random() * self.pct))

# %% [markdown]
# **Test the transform**

# %%
rand_pixel_copy_tf = RandPixelCopy(pct=0.02)

# Convert the PIL image to a tensor
img_tensor = transforms.PILToTensor()(sample_img)#[None]
print(img_tensor.shape)

# Apply the `rand_pixel_copy_tf` transform to the image tensor
tensor_to_pil(rand_pixel_copy_tf(img_tensor))
# Out:
# torch.Size([3, 512, 512])
# <PIL.Image.Image image mode=RGB size=512x512>

# %% [markdown]
# **Random Square Pixel Copy Transform**

# %%
def rand_square_pixel_copy(img_tensor:torch.Tensor, square_pct:float, pixel_pct:float):
    """
    Copy data from a randomly selected set of pixels of a randomly selected square region to another randomly
    selected square region of a tensor.

    Args:
    img_tensor (torch.Tensor): The input tensor.
    square_pct (float): The percentage of the tensor's size to be used as the side length of the square regions.
    pixel_pct (float): The percentage of the pixels of the source square region to be copied.

    Returns:
    torch.Tensor: The modified input tensor.
    """
    # Get the shape of the tensor
    h, w = img_tensor.shape[-2:]
    
    # Calculate the size of the square
    szx = int(square_pct * h)
    szy = int(square_pct * w)
    
    # Calculate the top-left coordinate of the first square
    stx1 = int(random.random() * (1 - square_pct) * h)
    sty1 = int(random.random() * (1 - square_pct) * w)
    
    # Calculate the top-left coordinate of the second square
    stx2 = int(random.random() * (1 - square_pct) * h)
    sty2 = int(random.random() * (1 - square_pct) * w)
    
    # Copy the data from the second square to the first square
    source_pixels = rand_pixel_copy(img_tensor[..., stx2:stx2 + szx, sty2:sty2 + szy].clone(), pixel_pct)
    img_tensor[..., stx1:stx1 + szx, sty1:sty1 + szy] = source_pixels
    
    # Return the modified input tensor
    return img_tensor

# %%
class RandSquarePixelCopy(nn.Module):
    def __init__(self, square_pct=0.2, pixel_pct=1.0, min_num=0, max_num=4):
        """
        A PyTorch module that applies the `rand_square_pixel_copy` function to an input tensor.

        Args:
        square_pct (float, optional): The percentage of the tensor's size to be used as the side length of the
                                      square regions.
        pixel_pct (float, optional): The maximum percentage of the pixels of the source square region to be copied.
        min_num (int, optional): The minimum number of times the `rand_square_pixel_copy` function is applied to
                                 the input tensor.
        max_num (int, optional): The maximum number of times the `rand_square_pixel_copy` function is applied to
                                 the input tensor.
        """
        super().__init__()
        self.square_pct = square_pct
        self.pixel_pct = pixel_pct
        self.min_num = min_num
        self.max_num = max_num
        
    def forward(self, x):
        # Apply the `rand_square_pixel_copy` function to the input tensor
        for i in range(random.randint(self.min_num, self.max_num)):
            x = rand_square_pixel_copy(x, 
                                       max(0.1,random.random()*self.square_pct), 
                                       max(0.0025, random.random()*self.pixel_pct))
        return x

# %% [markdown]
# **Test the transform**

# %%
rand_square_pixel_copy_tf = RandSquarePixelCopy(square_pct=0.15, pixel_pct=1.0, min_num=1, max_num=1)

img_tensor = transforms.PILToTensor()(sample_img)#[None]
print(img_tensor.shape)

tensor_to_pil(rand_square_pixel_copy_tf(img_tensor))
# Out:
# torch.Size([3, 512, 512])
# <PIL.Image.Image image mode=RGB size=512x512>

# %% [markdown]
# **Resize Pad Transform**

# %%
class ResizePad(nn.Module):
    def __init__(self, max_sz=256, padding_mode='edge'):
        """
        A PyTorch module that resizes an image tensor and adds padding to make it a square tensor.

        Args:
        max_sz (int, optional): The size of the square tensor.
        padding_mode (str, optional): The padding mode used when adding padding to the tensor.
        """
        super().__init__()
        self.max_sz = max_sz
        self.padding_mode = padding_mode
        
    def forward(self, x):
        # Get the width and height of the image tensor
        w, h = TF.get_image_size(x)
        
        # Resize the image tensor so that its minimum dimension is equal to `max_sz`
        size = int(min(w, h) / (max(w, h) / self.max_sz))
        x = TF.resize(x, size=size)
        
        # Add padding to make the image tensor a square
        w, h = TF.get_image_size(x)
        offset = (self.max_sz - min(w, h)) // 2
        padding = [0, offset] if h < w else [offset, 0]
        x = TF.pad(x, padding=padding, padding_mode=self.padding_mode)
        x = TF.resize(x, size=[self.max_sz] * 2)
        
        return x

# %% [markdown]
# **Test the transform**

# %%
print(f"Source image: {sample_img.size}")

# Crop the source image
w, h = sample_img.size
cropped_img = sample_img.crop([0, h//4, w, h-h//4])
print(f"Cropped image: {cropped_img.size}")

# Create a `ResizePad` object
resize_pad = ResizePad(max_sz=256)

# Convert the cropped image to a tensor
img_tensor = transforms.PILToTensor()(cropped_img)[None]
print(f"Cropped tensor: {img_tensor.shape}")

# Resize and pad the tensor
resized_tensor = resize_pad(img_tensor)
print(f"Padded tensor: {resized_tensor.shape}")

# Apply random pixel copy to the resized and padded tensor
tensor_to_pil(rand_pixel_copy(resized_tensor, 0.0125))
# Out:
# Source image: (512, 512)
# Cropped image: (512, 256)
# Cropped tensor: torch.Size([1, 3, 256, 512])
# Padded tensor: torch.Size([1, 3, 256, 256])
# <PIL.Image.Image image mode=RGB size=256x256>

# %% [markdown]
# **Trivial Augmentation**

# %%
# Create a TrivialAugmentWide object
trivial_aug = transforms.TrivialAugmentWide()

# Convert the image to a tensor
img_tensor = transforms.PILToTensor()(sample_img)[None]
print(img_tensor.shape)

# Apply the TrivialAugmentWide to the tensor
tensor_to_pil(trivial_aug(img_tensor))
# Out:
# torch.Size([1, 3, 512, 512])
# <PIL.Image.Image image mode=RGB size=512x512>

# %% [markdown]
# **Define training dataset class**

# %%
class ImageDataset(Dataset):
    def __init__(self, img_paths, classes, tfms):
        # Store the arguments as instance variables
        self.img_paths = img_paths
        self.classes = classes
        self.tfms = tfms
        
        # Create a mapping from class names to class indices
        self.class_to_idx = {c: i for i, c in enumerate(self.classes)}

    def __len__(self):
        # Return the number of images in the dataset
        return len(self.img_paths)

    def __getitem__(self, index):
        # Get the path of the image at the given index
        img_path = self.img_paths[index]
        
        # Get the label of the image
        label = self.class_to_idx[img_path.parent.name]
        
        # Open the image
        image = Image.open(img_path).convert('RGB')
        
        return self.tfms(image), label

# %% [markdown]
# **Set training and validation sets**

# %%
# Choose a subset of the image paths
img_paths_subset = random.sample(img_paths, int(len(img_paths)*0.9))

# Shuffle the subset of image paths
random.shuffle(img_paths_subset)

# Define the percentage of the images that should be used for training
train_percentage = 0.9

# Calculate the index at which to split the subset of image paths into training and validation sets
split_index = int(len(img_paths_subset)*train_percentage)

# Split the subset of image paths into training and validation sets
train_paths = img_paths_subset[:split_index]
val_path = img_paths_subset[split_index:]

# %% [markdown]
# **Set training image size**

# %%
train_sz = (256,256)

# %% [markdown]
# **Set normalization stats**

# %%
# normalization stats for imagenet
norm_stats = [0.485, 0.456, 0.406], [0.229, 0.224, 0.225]

# %% [markdown]
# **Initialize datasets**

# %%
# Set transforms for training set
train_tfms = [
    ResizePad(max_sz=max(train_sz)),
    transforms.TrivialAugmentWide(),
    transforms.ToTensor(),
    transforms.Normalize(*norm_stats),
#     RandSquareCopy(pct=0.2, min_num=1, max_num=1),
#     RandPixelCopy(pct=0.02),
#     RandSquarePixelCopy(square_pct=0.2, pixel_pct=0.5, min_num=1, max_num=1),
]
                             
# create the training dataset using the composed transformations
train_dataset = ImageDataset(img_paths=train_paths, 
                             classes=class_names,
                             tfms=transforms.Compose(train_tfms))

# Set transforms for validation set
valid_tfms = [
    ResizePad(max_sz=max(train_sz)),
    transforms.ToTensor(),
    transforms.Normalize(*norm_stats),
]

# create the validation dataset
valid_dataset = ImageDataset(img_paths=val_path, 
                             classes=class_names,
                             tfms=transforms.Compose(valid_tfms))

# print the length of the training and validation datasets
len(train_dataset), len(valid_dataset)
# Out:
# (124567, 13841)

# %% [markdown]
# **Inspect training set sample**

# %%
display_df((tensor_stats_df(train_dataset[0][0])))
# Out:
# <style type="text/css">
# #T_77055 th {
#   text-align: left;
# }
# #T_77055_row0_col0, #T_77055_row1_col0, #T_77055_row2_col0, #T_77055_row3_col0, #T_77055_row4_col0 {
#   width: auto;
#   text-align: left;
# }
# </style>
# <table id="T_77055">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_77055_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_77055_level0_row0" class="row_heading level0 row0" >mean</th>
#       <td id="T_77055_row0_col0" class="data row0 col0" >-0.189751</td>
#     </tr>
#     <tr>
#       <th id="T_77055_level0_row1" class="row_heading level0 row1" >std</th>
#       <td id="T_77055_row1_col0" class="data row1 col0" >0.874407</td>
#     </tr>
#     <tr>
#       <th id="T_77055_level0_row2" class="row_heading level0 row2" >min</th>
#       <td id="T_77055_row2_col0" class="data row2 col0" >-2.083654</td>
#     </tr>
#     <tr>
#       <th id="T_77055_level0_row3" class="row_heading level0 row3" >max</th>
#       <td id="T_77055_row3_col0" class="data row3 col0" >2.273987</td>
#     </tr>
#     <tr>
#       <th id="T_77055_level0_row4" class="row_heading level0 row4" >shape</th>
#       <td id="T_77055_row4_col0" class="data row4 col0" >torch.Size([3, 256, 256])</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Inspect validation set sample**

# %%
display_df(tensor_stats_df(valid_dataset[0][0]))
# Out:
# <style type="text/css">
# #T_f1caa th {
#   text-align: left;
# }
# #T_f1caa_row0_col0, #T_f1caa_row1_col0, #T_f1caa_row2_col0, #T_f1caa_row3_col0, #T_f1caa_row4_col0 {
#   width: auto;
#   text-align: left;
# }
# </style>
# <table id="T_f1caa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f1caa_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f1caa_level0_row0" class="row_heading level0 row0" >mean</th>
#       <td id="T_f1caa_row0_col0" class="data row0 col0" >-1.042794</td>
#     </tr>
#     <tr>
#       <th id="T_f1caa_level0_row1" class="row_heading level0 row1" >std</th>
#       <td id="T_f1caa_row1_col0" class="data row1 col0" >0.413175</td>
#     </tr>
#     <tr>
#       <th id="T_f1caa_level0_row2" class="row_heading level0 row2" >min</th>
#       <td id="T_f1caa_row2_col0" class="data row2 col0" >-2.100779</td>
#     </tr>
#     <tr>
#       <th id="T_f1caa_level0_row3" class="row_heading level0 row3" >max</th>
#       <td id="T_f1caa_row3_col0" class="data row3 col0" >1.546793</td>
#     </tr>
#     <tr>
#       <th id="T_f1caa_level0_row4" class="row_heading level0 row4" >shape</th>
#       <td id="T_f1caa_row4_col0" class="data row4 col0" >torch.Size([3, 256, 256])</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Set training batch size**

# %%
bs = 32

# %% [markdown]
# **Initialzie dataloaders**

# %%
train_dataloader = DataLoader(train_dataset, 
                              batch_size=bs, 
                              shuffle=True, 
                              num_workers=multiprocessing.cpu_count())

valid_dataloader = DataLoader(valid_dataset, batch_size=bs)

dls = DataLoaders(train_dataloader, valid_dataloader)

# Print the number of batches in the training and validation dataloaders
len(dls.train), len(dls.valid)
# Out:
# (3893, 433)

# %% [markdown]
# **List available ResNet18 models**

# %%
display_df(pd.DataFrame(timm.list_models('resnet18*', pretrained=True)))
# Out:
# <style type="text/css">
# #T_33d8e th {
#   text-align: left;
# }
# #T_33d8e_row0_col0, #T_33d8e_row1_col0 {
#   width: auto;
#   text-align: left;
# }
# </style>
# <table id="T_33d8e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_33d8e_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_33d8e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_33d8e_row0_col0" class="data row0 col0" >resnet18</td>
#     </tr>
#     <tr>
#       <th id="T_33d8e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_33d8e_row1_col0" class="data row1 col0" >resnet18d</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Inspect config for ResNet18 model**

# %%
# Import the convnext module
from timm.models import resnet

# Choose the resnet model
resnet_model = 'resnet18d'

# Get the default configuration of the chosen model as a Pandas DataFrame
display_df(pd.DataFrame.from_dict(resnet.default_cfgs[resnet_model], orient='index'))
# Out:
# <style type="text/css">
# #T_fa20f th {
#   text-align: left;
# }
# #T_fa20f_row0_col0, #T_fa20f_row1_col0, #T_fa20f_row2_col0, #T_fa20f_row3_col0, #T_fa20f_row4_col0, #T_fa20f_row5_col0, #T_fa20f_row6_col0, #T_fa20f_row7_col0, #T_fa20f_row8_col0, #T_fa20f_row9_col0 {
#   width: auto;
#   text-align: left;
# }
# </style>
# <table id="T_fa20f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fa20f_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa20f_level0_row0" class="row_heading level0 row0" >url</th>
#       <td id="T_fa20f_row0_col0" class="data row0 col0" >https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-weights/resnet18d_ra2-48a79e06.pth</td>
#     </tr>
#     <tr>
#       <th id="T_fa20f_level0_row1" class="row_heading level0 row1" >num_classes</th>
#       <td id="T_fa20f_row1_col0" class="data row1 col0" >1000</td>
#     </tr>
#     <tr>
#       <th id="T_fa20f_level0_row2" class="row_heading level0 row2" >input_size</th>
#       <td id="T_fa20f_row2_col0" class="data row2 col0" >(3, 224, 224)</td>
#     </tr>
#     <tr>
#       <th id="T_fa20f_level0_row3" class="row_heading level0 row3" >pool_size</th>
#       <td id="T_fa20f_row3_col0" class="data row3 col0" >(7, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_fa20f_level0_row4" class="row_heading level0 row4" >crop_pct</th>
#       <td id="T_fa20f_row4_col0" class="data row4 col0" >0.875000</td>
#     </tr>
#     <tr>
#       <th id="T_fa20f_level0_row5" class="row_heading level0 row5" >interpolation</th>
#       <td id="T_fa20f_row5_col0" class="data row5 col0" >bicubic</td>
#     </tr>
#     <tr>
#       <th id="T_fa20f_level0_row6" class="row_heading level0 row6" >mean</th>
#       <td id="T_fa20f_row6_col0" class="data row6 col0" >(0.485, 0.456, 0.406)</td>
#     </tr>
#     <tr>
#       <th id="T_fa20f_level0_row7" class="row_heading level0 row7" >std</th>
#       <td id="T_fa20f_row7_col0" class="data row7 col0" >(0.229, 0.224, 0.225)</td>
#     </tr>
#     <tr>
#       <th id="T_fa20f_level0_row8" class="row_heading level0 row8" >first_conv</th>
#       <td id="T_fa20f_row8_col0" class="data row8 col0" >conv1.0</td>
#     </tr>
#     <tr>
#       <th id="T_fa20f_level0_row9" class="row_heading level0 row9" >classifier</th>
#       <td id="T_fa20f_row9_col0" class="data row9 col0" >fc</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Load ResNet18 model**

# %%
# Load the resenet model
resnet18 = timm.create_model(resnet_model, pretrained=True, num_classes=len(class_names))

# Set the device and data type
resnet18 = resnet18.to(device=device, dtype=dtype).eval()
resnet18.device = device

# %% [markdown]
# **Select model**

# %%
model = resnet18

# %% [markdown]
# **Get model summary**

# %%
# Define the input to the model
test_inp = torch.randn(1, 3, *train_sz).to(device)

# Get a summary of the model as a Pandas DataFrame
summary_df = markdown_to_pandas(f"{get_module_summary(model, [test_inp])}")

# Filter the summary to only contain Conv2d layers and the model
summary_df = summary_df[(summary_df.index == 0) | (summary_df['Type'] == 'Conv2d')]

# Remove the column "Contains Uninitialized Parameters?"
display_df(summary_df.drop('Contains Uninitialized Parameters?', axis=1))
# Out:
# <style type="text/css">
# #T_10e27 th {
#   text-align: left;
# }
# #T_10e27_row0_col0, #T_10e27_row0_col1, #T_10e27_row0_col2, #T_10e27_row0_col3, #T_10e27_row0_col4, #T_10e27_row0_col5, #T_10e27_row0_col6, #T_10e27_row0_col7, #T_10e27_row1_col0, #T_10e27_row1_col1, #T_10e27_row1_col2, #T_10e27_row1_col3, #T_10e27_row1_col4, #T_10e27_row1_col5, #T_10e27_row1_col6, #T_10e27_row1_col7, #T_10e27_row2_col0, #T_10e27_row2_col1, #T_10e27_row2_col2, #T_10e27_row2_col3, #T_10e27_row2_col4, #T_10e27_row2_col5, #T_10e27_row2_col6, #T_10e27_row2_col7, #T_10e27_row3_col0, #T_10e27_row3_col1, #T_10e27_row3_col2, #T_10e27_row3_col3, #T_10e27_row3_col4, #T_10e27_row3_col5, #T_10e27_row3_col6, #T_10e27_row3_col7, #T_10e27_row4_col0, #T_10e27_row4_col1, #T_10e27_row4_col2, #T_10e27_row4_col3, #T_10e27_row4_col4, #T_10e27_row4_col5, #T_10e27_row4_col6, #T_10e27_row4_col7, #T_10e27_row5_col0, #T_10e27_row5_col1, #T_10e27_row5_col2, #T_10e27_row5_col3, #T_10e27_row5_col4, #T_10e27_row5_col5, #T_10e27_row5_col6, #T_10e27_row5_col7, #T_10e27_row6_col0, #T_10e27_row6_col1, #T_10e27_row6_col2, #T_10e27_row6_col3, #T_10e27_row6_col4, #T_10e27_row6_col5, #T_10e27_row6_col6, #T_10e27_row6_col7, #T_10e27_row7_col0, #T_10e27_row7_col1, #T_10e27_row7_col2, #T_10e27_row7_col3, #T_10e27_row7_col4, #T_10e27_row7_col5, #T_10e27_row7_col6, #T_10e27_row7_col7, #T_10e27_row8_col0, #T_10e27_row8_col1, #T_10e27_row8_col2, #T_10e27_row8_col3, #T_10e27_row8_col4, #T_10e27_row8_col5, #T_10e27_row8_col6, #T_10e27_row8_col7, #T_10e27_row9_col0, #T_10e27_row9_col1, #T_10e27_row9_col2, #T_10e27_row9_col3, #T_10e27_row9_col4, #T_10e27_row9_col5, #T_10e27_row9_col6, #T_10e27_row9_col7, #T_10e27_row10_col0, #T_10e27_row10_col1, #T_10e27_row10_col2, #T_10e27_row10_col3, #T_10e27_row10_col4, #T_10e27_row10_col5, #T_10e27_row10_col6, #T_10e27_row10_col7, #T_10e27_row11_col0, #T_10e27_row11_col1, #T_10e27_row11_col2, #T_10e27_row11_col3, #T_10e27_row11_col4, #T_10e27_row11_col5, #T_10e27_row11_col6, #T_10e27_row11_col7, #T_10e27_row12_col0, #T_10e27_row12_col1, #T_10e27_row12_col2, #T_10e27_row12_col3, #T_10e27_row12_col4, #T_10e27_row12_col5, #T_10e27_row12_col6, #T_10e27_row12_col7, #T_10e27_row13_col0, #T_10e27_row13_col1, #T_10e27_row13_col2, #T_10e27_row13_col3, #T_10e27_row13_col4, #T_10e27_row13_col5, #T_10e27_row13_col6, #T_10e27_row13_col7, #T_10e27_row14_col0, #T_10e27_row14_col1, #T_10e27_row14_col2, #T_10e27_row14_col3, #T_10e27_row14_col4, #T_10e27_row14_col5, #T_10e27_row14_col6, #T_10e27_row14_col7, #T_10e27_row15_col0, #T_10e27_row15_col1, #T_10e27_row15_col2, #T_10e27_row15_col3, #T_10e27_row15_col4, #T_10e27_row15_col5, #T_10e27_row15_col6, #T_10e27_row15_col7, #T_10e27_row16_col0, #T_10e27_row16_col1, #T_10e27_row16_col2, #T_10e27_row16_col3, #T_10e27_row16_col4, #T_10e27_row16_col5, #T_10e27_row16_col6, #T_10e27_row16_col7, #T_10e27_row17_col0, #T_10e27_row17_col1, #T_10e27_row17_col2, #T_10e27_row17_col3, #T_10e27_row17_col4, #T_10e27_row17_col5, #T_10e27_row17_col6, #T_10e27_row17_col7, #T_10e27_row18_col0, #T_10e27_row18_col1, #T_10e27_row18_col2, #T_10e27_row18_col3, #T_10e27_row18_col4, #T_10e27_row18_col5, #T_10e27_row18_col6, #T_10e27_row18_col7, #T_10e27_row19_col0, #T_10e27_row19_col1, #T_10e27_row19_col2, #T_10e27_row19_col3, #T_10e27_row19_col4, #T_10e27_row19_col5, #T_10e27_row19_col6, #T_10e27_row19_col7, #T_10e27_row20_col0, #T_10e27_row20_col1, #T_10e27_row20_col2, #T_10e27_row20_col3, #T_10e27_row20_col4, #T_10e27_row20_col5, #T_10e27_row20_col6, #T_10e27_row20_col7, #T_10e27_row21_col0, #T_10e27_row21_col1, #T_10e27_row21_col2, #T_10e27_row21_col3, #T_10e27_row21_col4, #T_10e27_row21_col5, #T_10e27_row21_col6, #T_10e27_row21_col7, #T_10e27_row22_col0, #T_10e27_row22_col1, #T_10e27_row22_col2, #T_10e27_row22_col3, #T_10e27_row22_col4, #T_10e27_row22_col5, #T_10e27_row22_col6, #T_10e27_row22_col7 {
#   width: auto;
#   text-align: left;
# }
# </style>
# <table id="T_10e27">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_10e27_level0_col0" class="col_heading level0 col0" >Type</th>
#       <th id="T_10e27_level0_col1" class="col_heading level0 col1" ># Parameters</th>
#       <th id="T_10e27_level0_col2" class="col_heading level0 col2" ># Trainable Parameters</th>
#       <th id="T_10e27_level0_col3" class="col_heading level0 col3" >Size (bytes)</th>
#       <th id="T_10e27_level0_col4" class="col_heading level0 col4" >Forward FLOPs</th>
#       <th id="T_10e27_level0_col5" class="col_heading level0 col5" >Backward FLOPs</th>
#       <th id="T_10e27_level0_col6" class="col_heading level0 col6" >In size</th>
#       <th id="T_10e27_level0_col7" class="col_heading level0 col7" >Out size</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_10e27_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_10e27_row0_col0" class="data row0 col0" >ResNet</td>
#       <td id="T_10e27_row0_col1" class="data row0 col1" >11.2 M</td>
#       <td id="T_10e27_row0_col2" class="data row0 col2" >11.2 M</td>
#       <td id="T_10e27_row0_col3" class="data row0 col3" >44.9 M</td>
#       <td id="T_10e27_row0_col4" class="data row0 col4" >2.7 G</td>
#       <td id="T_10e27_row0_col5" class="data row0 col5" >5.3 G</td>
#       <td id="T_10e27_row0_col6" class="data row0 col6" >[1, 3, 256, 256]</td>
#       <td id="T_10e27_row0_col7" class="data row0 col7" >[1, 19]</td>
#     </tr>
#     <tr>
#       <th id="T_10e27_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_10e27_row1_col0" class="data row1 col0" >Conv2d</td>
#       <td id="T_10e27_row1_col1" class="data row1 col1" >864</td>
#       <td id="T_10e27_row1_col2" class="data row1 col2" >864</td>
#       <td id="T_10e27_row1_col3" class="data row1 col3" >3.5 K</td>
#       <td id="T_10e27_row1_col4" class="data row1 col4" >14.2 M</td>
#       <td id="T_10e27_row1_col5" class="data row1 col5" >14.2 M</td>
#       <td id="T_10e27_row1_col6" class="data row1 col6" >[1, 3, 256, 256]</td>
#       <td id="T_10e27_row1_col7" class="data row1 col7" >[1, 32, 128, 128]</td>
#     </tr>
#     <tr>
#       <th id="T_10e27_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_10e27_row2_col0" class="data row2 col0" >Conv2d</td>
#       <td id="T_10e27_row2_col1" class="data row2 col1" >9.2 K</td>
#       <td id="T_10e27_row2_col2" class="data row2 col2" >9.2 K</td>
#       <td id="T_10e27_row2_col3" class="data row2 col3" >36.9 K</td>
#       <td id="T_10e27_row2_col4" class="data row2 col4" >150 M</td>
#       <td id="T_10e27_row2_col5" class="data row2 col5" >301 M</td>
#       <td id="T_10e27_row2_col6" class="data row2 col6" >[1, 32, 128, 128]</td>
#       <td id="T_10e27_row2_col7" class="data row2 col7" >[1, 32, 128, 128]</td>
#     </tr>
#     <tr>
#       <th id="T_10e27_level0_row3" class="row_heading level0 row3" >8</th>
#       <td id="T_10e27_row3_col0" class="data row3 col0" >Conv2d</td>
#       <td id="T_10e27_row3_col1" class="data row3 col1" >18.4 K</td>
#       <td id="T_10e27_row3_col2" class="data row3 col2" >18.4 K</td>
#       <td id="T_10e27_row3_col3" class="data row3 col3" >73.7 K</td>
#       <td id="T_10e27_row3_col4" class="data row3 col4" >301 M</td>
#       <td id="T_10e27_row3_col5" class="data row3 col5" >603 M</td>
#       <td id="T_10e27_row3_col6" class="data row3 col6" >[1, 32, 128, 128]</td>
#       <td id="T_10e27_row3_col7" class="data row3 col7" >[1, 64, 128, 128]</td>
#     </tr>
#     <tr>
#       <th id="T_10e27_level0_row4" class="row_heading level0 row4" >14</th>
#       <td id="T_10e27_row4_col0" class="data row4 col0" >Conv2d</td>
#       <td id="T_10e27_row4_col1" class="data row4 col1" >36.9 K</td>
#       <td id="T_10e27_row4_col2" class="data row4 col2" >36.9 K</td>
#       <td id="T_10e27_row4_col3" class="data row4 col3" >147 K</td>
#       <td id="T_10e27_row4_col4" class="data row4 col4" >150 M</td>
#       <td id="T_10e27_row4_col5" class="data row4 col5" >301 M</td>
#       <td id="T_10e27_row4_col6" class="data row4 col6" >[1, 64, 64, 64]</td>
#       <td id="T_10e27_row4_col7" class="data row4 col7" >[1, 64, 64, 64]</td>
#     </tr>

# %% [markdown]
# **Define training callbacks**

# %%
class WandBCB(MetricsCB):
    """
    A Callback class that integrates with the Weights and Biases (W&B) platform to log training 
    and validation metrics, as well as sample figures during training.
    """
    order=100
    
    def __init__(self, config, *ms, project:str, name:str=None, **metrics):
        """
        Initialize the WandBCB class.
        
        Parameters:
            config (dict): Configuration parameters for the W&B run.
            ms (list): List of metrics to be logged.
            project (str): The name of the W&B project.
            name (str, optional): The name of the W&B run. Defaults to None.
            metrics (dict, optional): Additional metrics to be logged.
        """
        fc.store_attr()
        self.train = False
        super().__init__(*ms, **metrics)
        
    def before_fit(self, learn):
        """
        Initialize the W&B run.
        
        Parameters:
            learn (miniai.learner.Learner): The miniai Learner object.
        """
        # If a name for the run is provided, use it, otherwise use the default name
        if self.name:
            wandb.init(project=self.project, name=self.name, config=self.config)
        else:
            wandb.init(project=self.project, config=self.config)
            
    def after_fit(self, learn):
        """
        Finalize the W&B run.
        
        Parameters:
            learn (miniai.learner.Learner): The miniai Learner object.
        """
        wandb.finish()

    def _log(self, d):
        """
        Log the metrics to W&B.
        
        Parameters:
            d (dict): Dictionary of metrics.
        """
        # Log the metrics with a prefix of "train_" if in training mode, otherwise "val_"
        if self.train: 
            wandb.log({'train_'+m:float(d[m]) for m in self.all_metrics})
        else: 
            wandb.log({'val_'+m:float(d[m]) for m in self.all_metrics})

    def after_batch(self, learn):
        """
        Log the loss after a batch
        """
        super().after_batch(learn)
        # Log the batch loss to W&B
        wandb.log({'loss':learn.loss})
        
    def after_epoch(self, learn):
        """
        Update the training mode flag and call the parent class's `after_epoch` method.

        Parameters:
            learn (miniai.learner.Learner): The miniai Learner object.
        """
        # Update the training mode flag
        self.train = learn.training
        super().after_epoch(learn)

# %%
class OutOfBoundsCB(Callback):
    """
    A callback that exits the training session if the loss is not NaN or infinite.
    """
    def __init__(self, msg="Loss out of bounds"):
        fc.store_attr()
        
    def after_loss(self, learn):
        """
        Check if the loss is NaN or infinite.
        """
        if learn.loss.detach().isnan() or learn.loss.detach().isinf(): 
            print(self.msg)
            raise CancelFitException()

# %% [markdown]
# **Initialize callbacks**

# %%
metrics = MetricsCB(accuracy=MulticlassAccuracy())

cbs = [MixedPrecision(), 
       OutOfBoundsCB(),
       DeviceCB(), 
       metrics, 
       ProgressCB(plot=False),
      ]

# %% [markdown]
# **Set optimizer**

# %%
opt_func = partial(torch.optim.AdamW, eps=1e-5)

# %% [markdown]
# **Set learning rate scheduler**

# %%
lr = 1e-3
epochs = 3

tmax = epochs * len(dls.train)
sched = partial(torch.optim.lr_scheduler.OneCycleLR, max_lr=lr, total_steps=tmax)
cbs.append(BatchSchedCB(sched))

# %% [markdown]
# **Configure Weights & Biases project**

# %%
project_name = "miniai_data_augmentation"
# run_name = "baseline"
# run_name = "rand-square-cp-1"
# run_name = "rand-pixel-cp-1"
# run_name = "rand-square-pixel-cp-1"
run_name = "trivial-aug-item-1"

project_config = {'lr':lr, 'epochs':epochs}

wandbcb =  WandBCB(config=project_config, 
                   project=project_name,
                   name=run_name,
                   accuracy=MulticlassAccuracy()
                  )
cbs.append(wandbcb)

# %% [markdown]
# **Initialize learner**

# %%
learn = TrainLearner(model, dls, torch.nn.functional.cross_entropy, lr=lr, cbs=cbs, opt_func=opt_func)

# %% [markdown]
# **Train model**

# %%
learn.fit(epochs)
# Out:
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668112600018502, max=1.0…
# Tracking run with wandb version 0.13.10
# Run data is saved locally in <code>/media/innom-dt/Samsung_T3/Projects/GitHub/fastai-2022p2-notes/notebooks/wandb/run-20230228_170008-n3g4yotq</code>
# Syncing run <strong><a href='https://wandb.ai/millscj/miniai_data_augmentation/runs/n3g4yotq' target="_blank">trivial-aug-item-1</a></strong> to <a href='https://wandb.ai/millscj/miniai_data_augmentation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/millscj/miniai_data_augmentation' target="_blank">https://wandb.ai/millscj/miniai_data_augmentation</a>
#  View run at <a href='https://wandb.ai/millscj/miniai_data_augmentation/runs/n3g4yotq' target="_blank">https://wandb.ai/millscj/miniai_data_augmentation/runs/n3g4yotq</a>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.845</td>
#       <td>0.537</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.960</td>
#       <td>0.134</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.935</td>
#       <td>0.208</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.988</td>
#       <td>0.036</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.971</td>
#       <td>0.091</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.994</td>
#       <td>0.020</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.003 MB of 0.016 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.177298…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss</td><td>█▄▂▂▂▃▂▂▃▁▂▂▁▂▂▂▂▁▂▁▂▁▂▁▂▁▁▁▂▁▁▁▁▁▁▁▁▂▁▁</td></tr><tr><td>train_accuracy</td><td>▁▆█</td></tr><tr><td>train_loss</td><td>█▃▁</td></tr><tr><td>val_accuracy</td><td>▁▇█</td></tr><tr><td>val_loss</td><td>█▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss</td><td>0.00156</td></tr><tr><td>train_accuracy</td><td>0.971</td></tr><tr><td>train_loss</td><td>0.091</td></tr><tr><td>val_accuracy</td><td>0.994</td></tr><tr><td>val_loss</td><td>0.02</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">trivial-aug-item-1</strong> at: <a href='https://wandb.ai/millscj/miniai_data_augmentation/runs/n3g4yotq' target="_blank">https://wandb.ai/millscj/miniai_data_augmentation/runs/n3g4yotq</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230228_170008-n3g4yotq/logs</code>

# %% [markdown]
# **Test model**

# %%
# Choose a random image from the list of image paths
img_path = random.choice(img_paths)

# Print the actual class of the chosen image
print(f"Class: {img_path.parent.name}")

# Open the image and resize it
sample_img = Image.open(img_path)
inp_img = resize_img(sample_img.copy(), 288)

# Convert the image to a tensor and move it to the device
img_tensor = pil_to_tensor(inp_img, *norm_stats).to(device=device)

# Make a prediction with the model
with torch.no_grad():
    pred = learn.model(img_tensor)

# Get the predicted class index and convert it to the class name
pred_class = train_dataset.classes[torch.argmax(torch.sigmoid(pred))]

# Print the predicted class
print(f"Predicted Class: {pred_class}")

# Display the image
sample_img
# Out:
# Class: no_gesture
# Predicted Class: no_gesture
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>

# %% [markdown]
# **Get test image paths**

# %%
# Create a dictionary mapping the filenames of the images to their file paths
img_dict = {f"{path.parent.stem}-{path.stem}": path for path in img_paths}

# Create a dictionary mapping the filenames of the images in the subset to their file paths
subset_dict = {f"{path.parent.stem}-{path.stem}": path for path in img_paths_subset}

# Find the file paths of the images that are not in the subset
test_paths = [path for k,path in img_dict.items() if k not in subset_dict]

# Print the number of images in the test set
len(test_paths)
# Out:
# 15379

# %% [markdown]
# **Perform inference on test set**

# %%
# Initialize a list to store the file paths of the images that were incorrectly classified
wrong_imgs = []

# Iterate through the test image paths
for path in tqdm(test_paths):
    # Get the actual class of the image
    target_cls = path.parent.name

    # Open and resize the image
    sample_img = Image.open(path)
    sample_img = resize_img(sample_img, 288)

    # Convert the image to a tensor and move it to the device
    img_tensor = pil_to_tensor(sample_img, *norm_stats).to(device=device)

    # Make a prediction with the model
    with torch.no_grad():
        pred = learn.model(img_tensor)

    # Get the predicted class index and convert it to the class name
    pred_cls = train_dataset.classes[torch.argmax(torch.sigmoid(pred))]
    
    # If the prediction is incorrect, add the file path to the list of wrong images
    if pred_cls != target_cls: 
        wrong_imgs.append(path)

# Print the number of images that were incorrectly classified
len(wrong_imgs)
# Out:
#   0%|          | 0/15379 [00:00<?, ?it/s]
# 78

# %% [markdown]
# **Set checkpoint directory**

# %%
# Create a directory to store the checkpoints if it does not already exist
checkpoint_dir = Path("./hagrid_checkpoints/")
checkpoint_dir.mkdir(parents=True, exist_ok=True)

# Print the checkpoint path
checkpoint_dir
# Out:
# Path('hagrid_checkpoints')

# %% [markdown]
# **Save model checkpoint**

# %%
torch.save(learn.model.state_dict(), checkpoint_dir/f"resnet18d-{run_name}.pth")

# %% [markdown]
# **Inspect the number of wrong predictions per class**

# %%
# Create a DataFrame from the list of incorrectly classified images
wrong_imgs_df = pd.DataFrame(wrong_imgs)

# Add a column to the DataFrame with the actual class of each image
wrong_imgs_df['class'] = wrong_imgs_df.apply(lambda row: Path(row[0]).parent.stem, axis=1)

# Create a DataFrame with the class distribution of the incorrectly classified images
class_dist_df = wrong_imgs_df['class'].value_counts().to_frame().rename(columns={"class":run_name})

# Set the index name to "class"
class_dist_df.rename_axis("class", inplace=True)

# Display the class distribution DataFrame
display_df(class_dist_df)
# Out:
# <style type="text/css">
# #T_ab4a0 th {
#   text-align: left;
# }
# #T_ab4a0_row0_col0, #T_ab4a0_row1_col0, #T_ab4a0_row2_col0, #T_ab4a0_row3_col0, #T_ab4a0_row4_col0, #T_ab4a0_row5_col0, #T_ab4a0_row6_col0, #T_ab4a0_row7_col0, #T_ab4a0_row8_col0, #T_ab4a0_row9_col0, #T_ab4a0_row10_col0, #T_ab4a0_row11_col0, #T_ab4a0_row12_col0, #T_ab4a0_row13_col0, #T_ab4a0_row14_col0, #T_ab4a0_row15_col0, #T_ab4a0_row16_col0, #T_ab4a0_row17_col0 {
#   width: auto;
#   text-align: left;
# }
# </style>
# <table id="T_ab4a0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ab4a0_level0_col0" class="col_heading level0 col0" >trivial-aug-item-1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >class</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ab4a0_level0_row0" class="row_heading level0 row0" >four</th>
#       <td id="T_ab4a0_row0_col0" class="data row0 col0" >10</td>
#     </tr>
#     <tr>
#       <th id="T_ab4a0_level0_row1" class="row_heading level0 row1" >like</th>
#       <td id="T_ab4a0_row1_col0" class="data row1 col0" >10</td>
#     </tr>
#     <tr>
#       <th id="T_ab4a0_level0_row2" class="row_heading level0 row2" >stop</th>
#       <td id="T_ab4a0_row2_col0" class="data row2 col0" >8</td>
#     </tr>
#     <tr>
#       <th id="T_ab4a0_level0_row3" class="row_heading level0 row3" >peace</th>
#       <td id="T_ab4a0_row3_col0" class="data row3 col0" >8</td>
#     </tr>
#     <tr>
#       <th id="T_ab4a0_level0_row4" class="row_heading level0 row4" >one</th>
#       <td id="T_ab4a0_row4_col0" class="data row4 col0" >7</td>
#     </tr>
#     <tr>
#       <th id="T_ab4a0_level0_row5" class="row_heading level0 row5" >three</th>
#       <td id="T_ab4a0_row5_col0" class="data row5 col0" >7</td>
#     </tr>
#     <tr>
#       <th id="T_ab4a0_level0_row6" class="row_heading level0 row6" >stop_inverted</th>
#       <td id="T_ab4a0_row6_col0" class="data row6 col0" >4</td>
#     </tr>
#     <tr>
#       <th id="T_ab4a0_level0_row7" class="row_heading level0 row7" >call</th>
#       <td id="T_ab4a0_row7_col0" class="data row7 col0" >3</td>
#     </tr>
#     <tr>
#       <th id="T_ab4a0_level0_row8" class="row_heading level0 row8" >palm</th>
#       <td id="T_ab4a0_row8_col0" class="data row8 col0" >3</td>
#     </tr>
#     <tr>
#       <th id="T_ab4a0_level0_row9" class="row_heading level0 row9" >no_gesture</th>
#       <td id="T_ab4a0_row9_col0" class="data row9 col0" >3</td>
#     </tr>
#     <tr>
#       <th id="T_ab4a0_level0_row10" class="row_heading level0 row10" >two_up</th>
#       <td id="T_ab4a0_row10_col0" class="data row10 col0" >3</td>
#     </tr>
#     <tr>
#       <th id="T_ab4a0_level0_row11" class="row_heading level0 row11" >dislike</th>
#       <td id="T_ab4a0_row11_col0" class="data row11 col0" >2</td>
#     </tr>
#     <tr>
#       <th id="T_ab4a0_level0_row12" class="row_heading level0 row12" >ok</th>
#       <td id="T_ab4a0_row12_col0" class="data row12 col0" >2</td>
#     </tr>
#     <tr>
#       <th id="T_ab4a0_level0_row13" class="row_heading level0 row13" >rock</th>
#       <td id="T_ab4a0_row13_col0" class="data row13 col0" >2</td>
#     </tr>
#     <tr>
#       <th id="T_ab4a0_level0_row14" class="row_heading level0 row14" >fist</th>
#       <td id="T_ab4a0_row14_col0" class="data row14 col0" >2</td>
#     </tr>
#     <tr>
#       <th id="T_ab4a0_level0_row15" class="row_heading level0 row15" >three2</th>
#       <td id="T_ab4a0_row15_col0" class="data row15 col0" >2</td>
#     </tr>
#     <tr>
#       <th id="T_ab4a0_level0_row16" class="row_heading level0 row16" >peace_inverted</th>
#       <td id="T_ab4a0_row16_col0" class="data row16 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_ab4a0_level0_row17" class="row_heading level0 row17" >mute</th>
#       <td id="T_ab4a0_row17_col0" class="data row17 col0" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Save DataFrame**

# %%
class_dist_df_path = checkpoint_dir/f"class_dist_df-{run_name}.json"
class_dist_df.to_json(class_dist_df_path)

# %% [markdown]
# **Get a list of json files**

# %%
# Get a list of paths to JSON files in the 'annotation_dir' directory
df_paths = glob(os.path.join(checkpoint_dir, "*.json"))

# Display the JSON file paths using a Pandas DataFrame
display_df(pd.DataFrame(df_paths))
# Out:
# <style type="text/css">
# #T_6399e th {
#   text-align: left;
# }
# #T_6399e_row0_col0, #T_6399e_row1_col0, #T_6399e_row2_col0, #T_6399e_row3_col0, #T_6399e_row4_col0 {
#   width: auto;
#   text-align: left;
# }
# </style>
# <table id="T_6399e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6399e_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6399e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6399e_row0_col0" class="data row0 col0" >hagrid_checkpoints/class_dist_df-baseline.json</td>
#     </tr>
#     <tr>
#       <th id="T_6399e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6399e_row1_col0" class="data row1 col0" >hagrid_checkpoints/class_dist_df-rand-pixel-cp-1.json</td>
#     </tr>
#     <tr>
#       <th id="T_6399e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6399e_row2_col0" class="data row2 col0" >hagrid_checkpoints/class_dist_df-rand-square-cp-1.json</td>
#     </tr>
#     <tr>
#       <th id="T_6399e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6399e_row3_col0" class="data row3 col0" >hagrid_checkpoints/class_dist_df-rand-square-pixel-cp-1.json</td>
#     </tr>
#     <tr>
#       <th id="T_6399e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6399e_row4_col0" class="data row4 col0" >hagrid_checkpoints/class_dist_df-trivial-aug-item-1.json</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Load and concatenate DataFrames**

# %%
# Create a generator that reads the class distribution data from each file in df_paths
class_dist_dfs = (pd.read_json(f).rename_axis('class') for f in df_paths)

# Concatenate the class distribution data into a single DataFrame
class_dist_agg_df = pd.concat(class_dist_dfs, axis=1, sort=False)

# Compute the sum of the class distribution data for each run
sums = class_dist_agg_df.sum(axis=0)

# Add a row to the DataFrame with the totals
class_dist_agg_df.loc['Total'] = sums

# Fill any missing values with 0 and convert the values to integers
display_df(class_dist_agg_df.fillna(0).astype(int))
# Out:
# <style type="text/css">
# #T_7d09c th {
#   text-align: left;
# }
# #T_7d09c_row0_col0, #T_7d09c_row0_col1, #T_7d09c_row0_col2, #T_7d09c_row0_col3, #T_7d09c_row0_col4, #T_7d09c_row1_col0, #T_7d09c_row1_col1, #T_7d09c_row1_col2, #T_7d09c_row1_col3, #T_7d09c_row1_col4, #T_7d09c_row2_col0, #T_7d09c_row2_col1, #T_7d09c_row2_col2, #T_7d09c_row2_col3, #T_7d09c_row2_col4, #T_7d09c_row3_col0, #T_7d09c_row3_col1, #T_7d09c_row3_col2, #T_7d09c_row3_col3, #T_7d09c_row3_col4, #T_7d09c_row4_col0, #T_7d09c_row4_col1, #T_7d09c_row4_col2, #T_7d09c_row4_col3, #T_7d09c_row4_col4, #T_7d09c_row5_col0, #T_7d09c_row5_col1, #T_7d09c_row5_col2, #T_7d09c_row5_col3, #T_7d09c_row5_col4, #T_7d09c_row6_col0, #T_7d09c_row6_col1, #T_7d09c_row6_col2, #T_7d09c_row6_col3, #T_7d09c_row6_col4, #T_7d09c_row7_col0, #T_7d09c_row7_col1, #T_7d09c_row7_col2, #T_7d09c_row7_col3, #T_7d09c_row7_col4, #T_7d09c_row8_col0, #T_7d09c_row8_col1, #T_7d09c_row8_col2, #T_7d09c_row8_col3, #T_7d09c_row8_col4, #T_7d09c_row9_col0, #T_7d09c_row9_col1, #T_7d09c_row9_col2, #T_7d09c_row9_col3, #T_7d09c_row9_col4, #T_7d09c_row10_col0, #T_7d09c_row10_col1, #T_7d09c_row10_col2, #T_7d09c_row10_col3, #T_7d09c_row10_col4, #T_7d09c_row11_col0, #T_7d09c_row11_col1, #T_7d09c_row11_col2, #T_7d09c_row11_col3, #T_7d09c_row11_col4, #T_7d09c_row12_col0, #T_7d09c_row12_col1, #T_7d09c_row12_col2, #T_7d09c_row12_col3, #T_7d09c_row12_col4, #T_7d09c_row13_col0, #T_7d09c_row13_col1, #T_7d09c_row13_col2, #T_7d09c_row13_col3, #T_7d09c_row13_col4, #T_7d09c_row14_col0, #T_7d09c_row14_col1, #T_7d09c_row14_col2, #T_7d09c_row14_col3, #T_7d09c_row14_col4, #T_7d09c_row15_col0, #T_7d09c_row15_col1, #T_7d09c_row15_col2, #T_7d09c_row15_col3, #T_7d09c_row15_col4, #T_7d09c_row16_col0, #T_7d09c_row16_col1, #T_7d09c_row16_col2, #T_7d09c_row16_col3, #T_7d09c_row16_col4, #T_7d09c_row17_col0, #T_7d09c_row17_col1, #T_7d09c_row17_col2, #T_7d09c_row17_col3, #T_7d09c_row17_col4, #T_7d09c_row18_col0, #T_7d09c_row18_col1, #T_7d09c_row18_col2, #T_7d09c_row18_col3, #T_7d09c_row18_col4, #T_7d09c_row19_col0, #T_7d09c_row19_col1, #T_7d09c_row19_col2, #T_7d09c_row19_col3, #T_7d09c_row19_col4 {
#   width: auto;
#   text-align: left;
# }
# </style>
# <table id="T_7d09c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d09c_level0_col0" class="col_heading level0 col0" >baseline</th>
#       <th id="T_7d09c_level0_col1" class="col_heading level0 col1" >rand-pixel-cp-1</th>
#       <th id="T_7d09c_level0_col2" class="col_heading level0 col2" >rand-square-cp-1</th>
#       <th id="T_7d09c_level0_col3" class="col_heading level0 col3" >rand-square-pixel-cp-1</th>
#       <th id="T_7d09c_level0_col4" class="col_heading level0 col4" >trivial-aug-item-1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >class</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d09c_level0_row0" class="row_heading level0 row0" >call</th>
#       <td id="T_7d09c_row0_col0" class="data row0 col0" >5</td>
#       <td id="T_7d09c_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_7d09c_row0_col2" class="data row0 col2" >7</td>
#       <td id="T_7d09c_row0_col3" class="data row0 col3" >7</td>
#       <td id="T_7d09c_row0_col4" class="data row0 col4" >3</td>
#     </tr>
#     <tr>
#       <th id="T_7d09c_level0_row1" class="row_heading level0 row1" >dislike</th>
#       <td id="T_7d09c_row1_col0" class="data row1 col0" >4</td>
#       <td id="T_7d09c_row1_col1" class="data row1 col1" >4</td>
#       <td id="T_7d09c_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_7d09c_row1_col3" class="data row1 col3" >3</td>
#       <td id="T_7d09c_row1_col4" class="data row1 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_7d09c_level0_row2" class="row_heading level0 row2" >fist</th>
#       <td id="T_7d09c_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_7d09c_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_7d09c_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_7d09c_row2_col3" class="data row2 col3" >3</td>
#       <td id="T_7d09c_row2_col4" class="data row2 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_7d09c_level0_row3" class="row_heading level0 row3" >four</th>
#       <td id="T_7d09c_row3_col0" class="data row3 col0" >8</td>
#       <td id="T_7d09c_row3_col1" class="data row3 col1" >8</td>
#       <td id="T_7d09c_row3_col2" class="data row3 col2" >10</td>
#       <td id="T_7d09c_row3_col3" class="data row3 col3" >7</td>
#       <td id="T_7d09c_row3_col4" class="data row3 col4" >10</td>
#     </tr>
#     <tr>
#       <th id="T_7d09c_level0_row4" class="row_heading level0 row4" >like</th>
#       <td id="T_7d09c_row4_col0" class="data row4 col0" >11</td>
#       <td id="T_7d09c_row4_col1" class="data row4 col1" >10</td>
#       <td id="T_7d09c_row4_col2" class="data row4 col2" >9</td>
#       <td id="T_7d09c_row4_col3" class="data row4 col3" >9</td>
#       <td id="T_7d09c_row4_col4" class="data row4 col4" >10</td>
#     </tr>
#     <tr>
#       <th id="T_7d09c_level0_row5" class="row_heading level0 row5" >mute</th>
#       <td id="T_7d09c_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_7d09c_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_7d09c_row5_col2" class="data row5 col2" >2</td>
#       <td id="T_7d09c_row5_col3" class="data row5 col3" >2</td>
#       <td id="T_7d09c_row5_col4" class="data row5 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7d09c_level0_row6" class="row_heading level0 row6" >no_gesture</th>
#       <td id="T_7d09c_row6_col0" class="data row6 col0" >4</td>
#       <td id="T_7d09c_row6_col1" class="data row6 col1" >6</td>
#       <td id="T_7d09c_row6_col2" class="data row6 col2" >5</td>
#       <td id="T_7d09c_row6_col3" class="data row6 col3" >5</td>
#       <td id="T_7d09c_row6_col4" class="data row6 col4" >3</td>
#     </tr>
#     <tr>
#       <th id="T_7d09c_level0_row7" class="row_heading level0 row7" >ok</th>
#       <td id="T_7d09c_row7_col0" class="data row7 col0" >5</td>
#       <td id="T_7d09c_row7_col1" class="data row7 col1" >4</td>
#       <td id="T_7d09c_row7_col2" class="data row7 col2" >2</td>
#       <td id="T_7d09c_row7_col3" class="data row7 col3" >4</td>
#       <td id="T_7d09c_row7_col4" class="data row7 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_7d09c_level0_row8" class="row_heading level0 row8" >one</th>
#       <td id="T_7d09c_row8_col0" class="data row8 col0" >13</td>
#       <td id="T_7d09c_row8_col1" class="data row8 col1" >10</td>
#       <td id="T_7d09c_row8_col2" class="data row8 col2" >7</td>
#       <td id="T_7d09c_row8_col3" class="data row8 col3" >7</td>
#       <td id="T_7d09c_row8_col4" class="data row8 col4" >7</td>
#     </tr>
#     <tr>
#       <th id="T_7d09c_level0_row9" class="row_heading level0 row9" >palm</th>
#       <td id="T_7d09c_row9_col0" class="data row9 col0" >6</td>
#       <td id="T_7d09c_row9_col1" class="data row9 col1" >3</td>
#       <td id="T_7d09c_row9_col2" class="data row9 col2" >4</td>
#       <td id="T_7d09c_row9_col3" class="data row9 col3" >2</td>
#       <td id="T_7d09c_row9_col4" class="data row9 col4" >3</td>
#     </tr>
#     <tr>
#       <th id="T_7d09c_level0_row10" class="row_heading level0 row10" >peace</th>
#       <td id="T_7d09c_row10_col0" class="data row10 col0" >5</td>
#       <td id="T_7d09c_row10_col1" class="data row10 col1" >3</td>
#       <td id="T_7d09c_row10_col2" class="data row10 col2" >5</td>
#       <td id="T_7d09c_row10_col3" class="data row10 col3" >8</td>
#       <td id="T_7d09c_row10_col4" class="data row10 col4" >8</td>
#     </tr>
#     <tr>
#       <th id="T_7d09c_level0_row11" class="row_heading level0 row11" >peace_inverted</th>
#       <td id="T_7d09c_row11_col0" class="data row11 col0" >3</td>
#       <td id="T_7d09c_row11_col1" class="data row11 col1" >0</td>
#       <td id="T_7d09c_row11_col2" class="data row11 col2" >3</td>
#       <td id="T_7d09c_row11_col3" class="data row11 col3" >4</td>
#       <td id="T_7d09c_row1
